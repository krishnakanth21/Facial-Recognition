# %%
import pandas as pd
import numpy as np
import os
import cv2
from matplotlib import pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\super\\Desktop'

# %%
os.chdir('C:\\Users\\hp\\Desktop\\Images')

# %%
os.listdir()
# Out:
# ['image1.jpg',
#  'image2.jpg',
#  'image3.jpg',
#  'image4.jpg',
#  'image5.jpg',
#  'image6.jpg',
#  'pic1.jpg',
#  'sample1.mp4',
#  'sample2.mp4']

# %%
test_image = cv2.imread('pic1.jpg')

# %%
test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(test_image_gray, cmap='gray')

# %%
def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# C:\\Users\\super\\Face-Detection-in-Python-using-OpenCV-master\\data\\haarcascades

# %%
haar_cascade_face = cv2.CascadeClassifier('E:\\Face-Detection-in-Python-using-OpenCV-master\\data\\haarcascades\\haarcascade_frontalface_default.xml')

# %%
pwd
# Out:
# 'C:\\Users\\hp\\Desktop\\Images'

# %%
faces_rects = haar_cascade_face.detectMultiScale(test_image_gray, scaleFactor = 1.2, minNeighbors = 5);

# Let us print the no. of faces found
print('Faces found: ', len(faces_rects))
# Out:
# Faces found:  6

# %%
for (x,y,w,h) in faces_rects:
     cv2.rectangle(test_image, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(convertToRGB(test_image))

# %%
def detect_faces(cascade, test_image, scaleFactor = 1.2):
    # create a copy of the image to prevent any changes to the original one.
    image_copy = test_image.copy()
    
    #convert the test image to gray scale as opencv face detector expects gray images
    gray_image = cv2.cvtColor(image_copy, cv2.COLOR_BGR2GRAY)
    
    # Applying the haar classifier to detect faces
    faces_rect = cascade.detectMultiScale(gray_image, scaleFactor=scaleFactor, minNeighbors=5)
    
    for (x, y, w, h) in faces_rect:
        cv2.rectangle(image_copy, (x, y), (x+w, y+h), (0, 255, 0), 15)
        
    return image_copy

# %%
#loading image
test_image2 = cv2.imread('pic1.jpg')

#call the function to detect faces
faces = detect_faces(haar_cascade_face, test_image2)

#convert to RGB and display image
plt.imshow(convertToRGB(faces))
