# %%
import cv2
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\hp\\ComputerVision'

# %%
os.chdir(r"C:\\Users\\hp\\Pictures")

# %%
os.listdir()
# Out:
# ['19758_en_1.jpg',
#  '483923.jpg',
#  '484627.jpg',
#  '546694.jpg',
#  '74776.jpg',
#  '74785.jpg',
#  '975508.jpg',
#  'Avengers-wallpapers-HD-free-download.jpg',
#  'batman_logo_7-wallpaper-3840x2160.jpg',
#  'BingImageOfTheDay.jpg',
#  'Camera Roll',
#  'desktop.ini',
#  'hey.deskthemepack',
#  'IMG-20180830-WA0001.jpg',
#  'IMG-20180830-WA0002.jpg',
#  'MarkSplitUp.jpg',
#  'RiME-4K-Ultra-HD-Wallpaper-3840x2160.jpg',
#  'Saved Pictures',
#  'Screenshot1new.png',
#  'Screenshots',
#  'spiderman-into-the-spider-verse-movie-2018-8k-j9-1536x864.jpg',
#  'wp1814943-guardians-of-the-galaxy-wallpapers.jpg']

# %%
img=cv2.imread("546694.jpg",1)

# %%
cv2.imshow("image!",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img,cmap = 'gray' ,interpolation = 'hamming')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
c = plt.imshow(img, cmap ='Greens',interpolation ='bicubic', origin ='upper') 
plt.colorbar(c)

# %%
img = np.zeros((512,512,3), np.uint8)
# Draw a diagonal line with thickness of 5 px
img = cv2.line(img,(0,0),(511,511),(0,0,170),5)
img = cv2.rectangle(img,(0,0),(511,511),(0,255,0),20)
img = cv2.circle(img,(200,200), 100, (0,255,255), -1)
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,'Hola!',(10,500), font, 4,(255,255,255),2,cv2.LINE_AA)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %% [markdown]
# # OnClick-draw circles

# %%
events = [i for i in dir(cv2) if 'EVENT' in i]
print(events)
# Out:
# ['EVENT_FLAG_ALTKEY', 'EVENT_FLAG_CTRLKEY', 'EVENT_FLAG_LBUTTON', 'EVENT_FLAG_MBUTTON', 'EVENT_FLAG_RBUTTON', 'EVENT_FLAG_SHIFTKEY', 'EVENT_LBUTTONDBLCLK', 'EVENT_LBUTTONDOWN', 'EVENT_LBUTTONUP', 'EVENT_MBUTTONDBLCLK', 'EVENT_MBUTTONDOWN', 'EVENT_MBUTTONUP', 'EVENT_MOUSEHWHEEL', 'EVENT_MOUSEMOVE', 'EVENT_MOUSEWHEEL', 'EVENT_RBUTTONDBLCLK', 'EVENT_RBUTTONDOWN', 'EVENT_RBUTTONUP']

# %%
def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDBLCLK:
        cv2.circle(img,(x,y),100,(255,0,0),-1)

# Create a black image, a window and bind the function to window
img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow('image')
cv2.setMouseCallback('image',draw_circle)

while(1):
    cv2.imshow('image',img)
    if cv2.waitKey(5) & 0xFF == 27:
        break
cv2.destroyAllWindows()

# %% [markdown]
# # Trackbar for colours

# %%
def nothing(x):
    pass

# Create a black image, a window
img = np.zeros((300,512,3), np.uint8)
cv2.namedWindow('image')

# create trackbars for color change
cv2.createTrackbar('R','image',0,255,nothing)
cv2.createTrackbar('G','image',0,255,nothing)
cv2.createTrackbar('B','image',0,255,nothing)

# create switch for ON/OFF functionality
switch = '0 : OFF \n1 : ON'
cv2.createTrackbar(switch, 'image',0,1,nothing)

while(1):
    cv2.imshow('image',img)
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break

    # get current positions of four trackbars
    r = cv2.getTrackbarPos('R','image')
    g = cv2.getTrackbarPos('G','image')
    b = cv2.getTrackbarPos('B','image')
    s = cv2.getTrackbarPos(switch,'image')

    if s == 0:
        img[:] = 0
    else:
        img[:] = [b,g,r]

cv2.destroyAllWindows()

# %%
img.itemset((10,10,2),100)
img.item(10,10,2)
# Out:
# 100

# %%
img.shape[0]*img.shape[1]*3==img.size
# Out:
# True

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
y=0
x=0
h=100
w=900
crop_img = img[y:y+h, x:x+w]
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
cv2.waitKey(0)
# Out:
# -1

# %%
print(img.shape)
print(crop_img.shape)
# Out:
# (1080, 1920, 3)
# (1080, 900, 3)

# %%
img1 = img
img2 = cv2.imread('Avengers-wallpapers-HD-free-download.jpg')

dst = cv2.addWeighted(img1,0.4,img2,0.6,0)

# plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
# plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
# plt.show()
cv2.imshow("image!",dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
